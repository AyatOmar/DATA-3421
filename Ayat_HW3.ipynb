# %% [markdown]
# <a href="https://colab.research.google.com/github/AyatOmar/DATA-3421/blob/main/Ayat_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
# %matplotlib inline

# %%
# !pwd
# Out:
# /content

# %%
os.getcwd()
# Out:
# '/content'

# %%
# !ls
# Out:
# charles.png  Panda.png	sample_data

# %% [markdown]
# # Loading and Displaying Image

# %%
#loading image using PIL
pic1 = Image.open("Panda.png")
#Converting PIL image to Numpy array
pic_array=np.asarray(pic1)
pic_array.shape
#loading image using Numpy
plt.imshow(pic_array)
#displaying dimensions and color channels
height, width, channels = pic_array.shape
print(f"Image Dimensions: {width} x {height}")
print(f"Number of Color Channels: {channels}")
# Out:
# Image Dimensions: 1522 x 1528
# Number of Color Channels: 4

# %%
pic_c = pic_array.copy()

# %% [markdown]
# # Color Space Conversion

# %%
import cv2

# %%
#converting from BGR to RGB
img = cv2.imread('Panda.png')
pic_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#displaying updated image
plt.imshow(pic_rgb)

# %%
plt.imshow(pic_c[:,:,1], cmap='gray') #RGB

# %% [markdown]
# # Image Resizing

# %%
## Resizing
plt.imshow(pic_rgb)

# %%
## Resizing
new_image = cv2.resize(pic_rgb,(600,300))
plt.imshow(new_image)

# %% [markdown]
# # Image Thresholding

# %%
ert,thresh1 = cv2.threshold(pic_rgb,100,250, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %%
ert,thresh1 = cv2.threshold(pic_rgb,200,250, cv2.THRESH_BINARY)
plt.imshow(thresh1, cmap='gray')

# %% [markdown]
# # Brightness Adjustment

# %%
img = load_img()
gamma = 15
effected_image = np.power(img,gamma)
display_img(effected_image)

# %% [markdown]
# # Blurring and Smoothing

# %%
### Smoothing and Blurring

def load_img():
    img = cv2.imread("Panda.png").astype(np.float32)/255
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    return img

# %%
def display_img(img):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img)

# %%
i = load_img()
display_img(i)

# %%
new_image2 = cv2.resize(pic_rgb,(20,20))
plt.imshow(new_image2)

# %%
new_image2 = cv2.resize(pic_rgb,(5,5))
plt.imshow(new_image2)

# %% [markdown]
# # Image Indexing and Cropping

# %%
p2 = pic_rgb[0:400, 500:600]
plt.imshow(p2)

# %% [markdown]
# # Image Rotation

# %%
pic2 = cv2.cvtColor(p2, cv2.COLOR_BGR2GRAY)
plt.imshow(pic2)

# %%
# Load the image
image = Image.open("Panda.png")

# Rotate the image by 45 degrees
rotated_image = image.rotate(45, expand=True)

# Display the rotated image
plt.imshow(rotated_image)
plt.show()

# %% [markdown]
# When rotating an image, some pixels may be lost due to cropping or interpolation. This can result in a loss of detail or artifacts in the rotated image. Padding the image with zeros or other background pixels before rotating can help to prevent loss of information.

# %% [markdown]
# # Image Flipping

# %%
### Flipping the image
f_img = cv2.flip(pic_rgb,0)
plt.imshow(f_img)

# %%
### Flipping the image
f_img = cv2.flip(pic_rgb,1)
plt.imshow(f_img)

# %% [markdown]
# Flipping images horizontally or vertically increases the diversity of the training dataset, helping the model generalize better to different orientations and variations in real-world scenarios. This augmentation technique aids in improving the robustness and performance of the model by exposing it to a broader range of variations that may be encountered during deployment

# %% [markdown]
# # Edge Detection

# %%
### Edge Dectection

img = cv2.imread("Panda.png",0)
edges = cv2.Canny(img,100,200)

## Display the edge
plt.imshow(edges,cmap='gray')

# %% [markdown]
# This is done by comparing the gradient magnitude to two threshold values, a lower threshold and an upper threshold. Pixels with gradient magnitudes below the lower threshold are considered to be background pixels.

# %% [markdown]
# # Gradients in Image

# %%
import cv2
import numpy as np

# Load the image
image = cv2.imread('Panda.png', 0)

# Apply the Sobel filter
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)

# Convert to polar coordinates
magnitude, direction = cv2.cartToPolar(sobel_x, sobel_y, angleInDegrees=True)

# Display the gradient magnitude and direction images
plt.subplot(121), plt.imshow(magnitude.astype(np.uint8)), plt.title('Gradient Direction')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(direction.astype(np.uint8)), plt.title('Gradient Magnitude')
plt.xticks([]), plt.yticks([])
plt.show()
